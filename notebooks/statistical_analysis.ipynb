# %% [markdown]
# # Statistical Analysis

# %%
from load_cleaned_data import load_cleaned_data

df = load_cleaned_data()

# %%
df
# Out:
# shape: (1_169, 13)
# ┌─────┬────────┬─────────────┬─────────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ age ┆ gender ┆ daily_socia ┆ platform_us ┆ … ┆ stress_lev ┆ anxiety_le ┆ addiction_ ┆ depression │
# │ --- ┆ ---    ┆ l_media_hou ┆ age         ┆   ┆ el         ┆ vel        ┆ level      ┆ _label     │
# │ i64 ┆ str    ┆ rs          ┆ ---         ┆   ┆ ---        ┆ ---        ┆ ---        ┆ ---        │
# │     ┆        ┆ ---         ┆ str         ┆   ┆ i64        ┆ i64        ┆ i64        ┆ i64        │
# │     ┆        ┆ f64         ┆             ┆   ┆            ┆            ┆            ┆            │
# ╞═════╪════════╪═════════════╪═════════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 18  ┆ male   ┆ 6.7         ┆ Instagram   ┆ … ┆ 5          ┆ 8          ┆ 3          ┆ 0          │
# │ 17  ┆ female ┆ 2.3         ┆ Instagram   ┆ … ┆ 3          ┆ 7          ┆ 7          ┆ 0          │
# ...
